# %%
import pandas as pd

# %%
from selenium import webdriver #criar um navegador
from selenium.webdriver.common.by import By #Localizar elementos (os itens de um site)
from selenium.webdriver.common.keys import Keys # Permite clicar em teclas do teclado

navegador = webdriver.Chrome()

navegador.get("https://www.ogol.com.br/edicao.php?id_edicao=162047")

#Time1
time_1 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[1]/td[3]/a').text
pontos_time_1 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[1]/td[4]/strong').text
jogos_time_1 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[1]/td[5]/a').text
vitorias_time_1 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[1]/td[6]/a').text
empates_time_1 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[1]/td[7]/a').text
derrotas_time_1 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[1]/td[8]/a').text
gols_pro_time_1 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[1]/td[9]/a').text
gols_contra_time_1 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[1]/td[10]/a').text


#Time2
time_2 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[2]/td[3]/a').text
pontos_time_2 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[2]/td[4]/strong').text
jogos_time_2 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[2]/td[5]/a').text
vitorias_time_2 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[2]/td[6]/a').text
empates_time_2 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[2]/td[7]/a').text
derrotas_time_2 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[2]/td[8]/a').text
gols_pro_time_2 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[2]/td[9]/a').text
gols_contra_time_2 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[2]/td[10]/a').text



#Time3
time_3 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[3]/td[3]/a').text
pontos_time_3 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[3]/td[4]/strong').text
jogos_time_3 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[3]/td[5]/a').text
vitorias_time_3 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[3]/td[6]/a').text
empates_time_3 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[3]/td[7]/a').text
derrotas_time_3 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[3]/td[8]/a').text
gols_pro_time_3 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[3]/td[9]/a').text
gols_contra_time_3 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[3]/td[10]/a').text


#Time4
time_4 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[4]/td[3]/a').text
pontos_time_4 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[4]/td[4]/strong').text
jogos_time_4 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[4]/td[5]/a').text
vitorias_time_4 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[4]/td[6]/a').text
empates_time_4 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[4]/td[7]/a').text
derrotas_time_4 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[4]/td[8]/a').text
gols_pro_time_4 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[4]/td[9]/a').text
gols_contra_time_4 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[4]/td[10]/a').text



#Time5
time_5 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[5]/td[3]/a').text
pontos_time_5 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[5]/td[4]/strong').text
jogos_time_5 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[5]/td[5]/a').text
vitorias_time_5 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[5]/td[6]/a').text
empates_time_5 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[5]/td[7]/a').text
derrotas_time_5 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[5]/td[8]/a').text
gols_pro_time_5 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[5]/td[9]/a').text
gols_contra_time_5 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[5]/td[10]/a').text



#Time6
time_6 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[6]/td[3]/a').text
pontos_time_6 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[6]/td[4]/strong').text
jogos_time_6 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[6]/td[5]/a').text
vitorias_time_6 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[6]/td[6]/a').text
empates_time_6 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[6]/td[7]/a').text
derrotas_time_6 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[6]/td[8]/a').text
gols_pro_time_6 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[6]/td[9]/a').text
gols_contra_time_6 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[6]/td[10]/a').text



#Time7
time_7 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[7]/td[3]/a').text
pontos_time_7 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[7]/td[4]/strong').text
jogos_time_7 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[7]/td[5]/a').text
vitorias_time_7 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[7]/td[6]/a').text
empates_time_7 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[7]/td[7]/a').text
derrotas_time_7 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[7]/td[8]/a').text
gols_pro_time_7 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[7]/td[9]/a').text
gols_contra_time_7 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[7]/td[10]/a').text



#Time8
time_8 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[8]/td[3]/a').text
pontos_time_8 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[8]/td[4]/strong').text
jogos_time_8 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[8]/td[5]/a').text
vitorias_time_8 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[8]/td[6]/a').text
empates_time_8 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[8]/td[7]/a').text
derrotas_time_8 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[8]/td[8]/a').text
gols_pro_time_8 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[8]/td[9]/a').text
gols_contra_time_8 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[8]/td[10]/a').text


#Time9
time_9 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[9]/td[3]/a').text
pontos_time_9 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[9]/td[4]/strong').text
jogos_time_9 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[9]/td[5]/a').text
vitorias_time_9 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[9]/td[6]/a').text
empates_time_9 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[9]/td[7]/a').text
derrotas_time_9 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[9]/td[8]/a').text
gols_pro_time_9 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[9]/td[9]/a').text
gols_contra_time_9 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[9]/td[10]/a').text


#Time10
time_10 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[10]/td[3]/a').text
pontos_time_10 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[10]/td[4]/strong').text
jogos_time_10 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[10]/td[5]/a').text
vitorias_time_10 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[10]/td[6]/a').text
empates_time_10 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[10]/td[7]/a').text
derrotas_time_10 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[10]/td[8]/a').text
gols_pro_time_10 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[10]/td[9]/a').text
gols_contra_time_10 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[10]/td[10]/a').text



#Time11
time_11 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[11]/td[3]/a').text
pontos_time_11 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[11]/td[4]/strong').text
jogos_time_11 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[11]/td[5]/a').text
vitorias_time_11 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[11]/td[6]/a').text
empates_time_11 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[11]/td[7]/a').text
derrotas_time_11 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[11]/td[8]/a').text
gols_pro_time_11 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[11]/td[9]/a').text
gols_contra_time_11 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[11]/td[10]/a').text



#Time12
time_12 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[12]/td[3]/a').text
pontos_time_12 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[12]/td[4]/strong').text
jogos_time_12 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[12]/td[5]/a').text
vitorias_time_12 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[12]/td[6]/a').text
empates_time_12 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[12]/td[7]/a').text
derrotas_time_12 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[12]/td[8]/a').text
gols_pro_time_12 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[12]/td[9]/a').text
gols_contra_time_12 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[12]/td[10]/a').text


#Time13
time_13 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[13]/td[3]/a').text
pontos_time_13 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[13]/td[4]/strong').text
jogos_time_13 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[13]/td[5]/a').text
vitorias_time_13 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[13]/td[6]/a').text
empates_time_13 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[13]/td[7]/a').text
derrotas_time_13 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[13]/td[8]/a').text
gols_pro_time_13 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[13]/td[9]/a').text
gols_contra_time_13 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[13]/td[10]/a').text

#Time14
time_14 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[14]/td[3]/a').text
pontos_time_14 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[14]/td[4]/strong').text
jogos_time_14 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[14]/td[5]/a').text
vitorias_time_14 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[14]/td[6]/a').text
empates_time_14 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[14]/td[7]/a').text
derrotas_time_14 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[14]/td[8]/a').text
gols_pro_time_14 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[14]/td[9]/a').text
gols_contra_time_14 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[14]/td[10]/a').text


#Time15
time_15 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[15]/td[3]/a').text
pontos_time_15 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[15]/td[4]/strong').text
jogos_time_15 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[15]/td[5]/a').text
vitorias_time_15 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[15]/td[6]/a').text
empates_time_15 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[15]/td[7]/a').text
derrotas_time_15 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[15]/td[8]/a').text
gols_pro_time_15 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[15]/td[9]/a').text
gols_contra_time_15 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[15]/td[10]/a').text


#Time16
time_16 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[16]/td[3]/a').text
pontos_time_16 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[16]/td[4]/strong').text
jogos_time_16 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[16]/td[5]/a').text
vitorias_time_16 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[16]/td[6]/a').text
empates_time_16 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[16]/td[7]/a').text
derrotas_time_16 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[16]/td[8]/a').text
gols_pro_time_16 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[16]/td[9]/a').text
gols_contra_time_16 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[16]/td[10]/a').text


#Time17
time_17 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[17]/td[3]/a').text
pontos_time_17 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[17]/td[4]/strong').text
jogos_time_17 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[17]/td[5]/a').text
vitorias_time_17 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[17]/td[6]/a').text
empates_time_17 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[17]/td[7]/a').text
derrotas_time_17 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[17]/td[8]/a').text
gols_pro_time_17 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[17]/td[9]/a').text
gols_contra_time_17 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[17]/td[10]/a').text


#Time18
time_18 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[18]/td[3]/a').text
pontos_time_18 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[18]/td[4]/strong').text
jogos_time_18 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[18]/td[5]/a').text
vitorias_time_18 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[18]/td[6]/a').text
empates_time_18 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[18]/td[7]/a').text
derrotas_time_18 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[18]/td[8]/a').text
gols_pro_time_18 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[18]/td[9]/a').text
gols_contra_time_18 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[18]/td[10]/a').text


#Time19
time_19 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[19]/td[3]/a').text
pontos_time_19 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[19]/td[4]/strong').text
jogos_time_19 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[19]/td[5]/a').text
vitorias_time_19 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[19]/td[6]/a').text
empates_time_19 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[19]/td[7]/a').text
derrotas_time_19 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[19]/td[8]/a').text
gols_pro_time_19 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[19]/td[9]/a').text
gols_contra_time_19 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[19]/td[10]/a').text


#Time20
time_20 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[20]/td[3]/a').text
pontos_time_20 = navegador.find_element(By.XPATH, '//*[@id="DataTables_Table_0"]/tbody/tr[20]/td[4]/strong').text
jogos_time_20 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[20]/td[5]/a').text
vitorias_time_20 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[20]/td[6]/a').text
empates_time_20 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[20]/td[7]/a').text
derrotas_time_20 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[20]/td[8]/a').text
gols_pro_time_20 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[20]/td[9]/a').text
gols_contra_time_20 = navegador.find_element(By.XPATH,'//*[@id="DataTables_Table_0"]/tbody/tr[20]/td[10]/a').text

# %%
times = [time_1 , time_2, time_3, time_4, time_5, time_6, time_7, time_8, time_9, time_10, time_11, time_12, time_13, time_14, time_15, time_16, time_17, time_18, time_19, time_20]
pontos = [pontos_time_1 , pontos_time_2, pontos_time_3, pontos_time_4, pontos_time_5, pontos_time_6, pontos_time_7, pontos_time_8, pontos_time_9, pontos_time_10, pontos_time_11, pontos_time_12, pontos_time_13, pontos_time_14, pontos_time_15, pontos_time_16, pontos_time_17, pontos_time_18, pontos_time_19, pontos_time_20]
jogos = [jogos_time_1 , jogos_time_2, jogos_time_3, jogos_time_4, jogos_time_5, jogos_time_6, jogos_time_7, jogos_time_8, jogos_time_9, jogos_time_10, jogos_time_11, jogos_time_12, jogos_time_13, jogos_time_14, jogos_time_15, jogos_time_16, jogos_time_17, jogos_time_18, jogos_time_19, jogos_time_20]
vitorias = [vitorias_time_1 , vitorias_time_2, vitorias_time_3, vitorias_time_4, vitorias_time_5, vitorias_time_6, vitorias_time_7, vitorias_time_8, vitorias_time_9, vitorias_time_10, vitorias_time_11, vitorias_time_12, vitorias_time_13, vitorias_time_14, vitorias_time_15, vitorias_time_16, vitorias_time_17, vitorias_time_18, vitorias_time_19, vitorias_time_20]
empates = [empates_time_1, empates_time_2, empates_time_3, empates_time_4, empates_time_5, empates_time_6, empates_time_7, empates_time_8, empates_time_9, empates_time_10, empates_time_11, empates_time_12, empates_time_13, empates_time_14, empates_time_15, empates_time_16, empates_time_17, empates_time_18, empates_time_19, empates_time_20]
derrotas = [derrotas_time_1 , derrotas_time_2, derrotas_time_3, derrotas_time_4, derrotas_time_5, derrotas_time_6, derrotas_time_7, derrotas_time_8, derrotas_time_9, derrotas_time_10, derrotas_time_11, derrotas_time_12, derrotas_time_13, derrotas_time_14, derrotas_time_15, derrotas_time_16, derrotas_time_17, derrotas_time_18, derrotas_time_19, derrotas_time_20]
gols_pro = [gols_pro_time_1, gols_pro_time_2, gols_pro_time_3, gols_pro_time_4, gols_pro_time_5, gols_pro_time_6, gols_pro_time_7, gols_pro_time_8, gols_pro_time_9, gols_pro_time_10, gols_pro_time_11, gols_pro_time_12, gols_pro_time_13, gols_pro_time_14, gols_pro_time_15, gols_pro_time_16, gols_pro_time_17, gols_pro_time_18, gols_pro_time_19, gols_pro_time_20]
gols_contra = [gols_contra_time_1, gols_contra_time_2, gols_contra_time_3, gols_contra_time_4, gols_contra_time_5, gols_contra_time_6, gols_contra_time_7, gols_contra_time_8, gols_contra_time_9, gols_contra_time_10, gols_contra_time_11, gols_contra_time_12, gols_contra_time_13, gols_contra_time_14, gols_contra_time_15, gols_contra_time_16, gols_contra_time_17, gols_contra_time_18, gols_contra_time_19, gols_contra_time_20]

# %%
tabela = pd.DataFrame({"Times": times, "Pontos": pontos, "Jogos": jogos, "Vitórias": vitorias, "Empates": empates, "Derrotas": derrotas, "Gols Pró": gols_pro, "Gols Contra": gols_contra})
tabela
# Out:
#                    Times Pontos Jogos Vitórias Empates Derrotas Gols Pró  \
# 0              Palmeiras     67    31       19      10        2       53
# 1          Internacional     57    31       15      12        4       48
# 2            Corinthians     54    31       15       9        7       38
# 3               Flamengo     52    31       15       7        9       50
# 4             Fluminense     51    31       15       6       10       48
# 5   Athletico Paranaense     48    31       13       9        9       37
# 6       Atlético Mineiro     47    31       12      11        8       38
# 7        América Mineiro     45    31       13       6       12       29
# 8               Botafogo     43    31       12       7       12       32
# 9              Fortaleza     41    31       11       8       12       32
# 10                Santos     40    31       10      10       11       36
# 11             São Paulo     40    30        9      13        8       41
# ...

# %%
tabela["Pontos"] = pd.to_numeric(tabela["Pontos"])
tabela["Jogos"] = pd.to_numeric(tabela["Jogos"])
tabela["Vitórias"] = pd.to_numeric(tabela["Vitórias"])
tabela["Empates"] = pd.to_numeric(tabela["Empates"])
tabela["Derrotas"] = pd.to_numeric(tabela["Derrotas"])
tabela["Gols Pró"] = pd.to_numeric(tabela["Gols Pró"])
tabela["Gols Contra"] = pd.to_numeric(tabela["Gols Contra"])

# %%
tabela
# Out:
#                    Times  Pontos  Jogos  Vitórias  Empates  Derrotas  \
# 0              Palmeiras      67     31        19       10         2
# 1          Internacional      57     31        15       12         4
# 2            Corinthians      54     31        15        9         7
# 3               Flamengo      52     31        15        7         9
# 4             Fluminense      51     31        15        6        10
# 5   Athletico Paranaense      48     31        13        9         9
# 6       Atlético Mineiro      47     31        12       11         8
# 7        América Mineiro      45     31        13        6        12
# 8               Botafogo      43     31        12        7        12
# 9              Fortaleza      41     31        11        8        12
# 10                Santos      40     31        10       10        11
# 11             São Paulo      40     30         9       13         8
# 12   Red Bull Bragantino      38     31         9       11        11
# ...

# %%
tabela.to_excel(r"M:\ARQUIVOS\Scripts Python\tabela_BR_2022.xlsx", index = False, sheet_name = "tabela_BR_22")
navegador.quit()

# %%
tabela.plot(tabela[y], kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 tabela.plot(tabela[y], kind='bar')
#
# NameError: name 'y' is not defined
